# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'Untitled.ipynb',
#  'fruits.txt',
#  'textpro.py',
#  'app1_sql.py',
#  'resources',
#  'temps_today.csv',
#  'basics.py',
#  '.ipynb_checkpoints',
#  'filereader.py',
#  'app1.py',
#  'data.txt']

# %%
import pandas

# %%
df1 = pandas.read_csv("resources/supermarkets/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("resources/supermarkets/supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel("resources/supermarkets/supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("resources/supermarkets/supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("resources/supermarkets/supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = df5.set_index("ID", drop=False)
df6
# Out:
#     ID          Address           City             State Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees
# ID
# 1        Madeira          8
# 2    Bready Shop         15
# 3    Super River         25
# 4     Ben's Shop         10
# 5        Sanchez         12
# 6     Richvalley         20

# %%
df6.loc["2":"4", "Address":"Country"]
# Out:
#            Address           City             State Country
# ID
# 2   735 Dolores St  San Francisco          CA 94119     USA
# 3      332 Hill St  San Francisco  California 94114     USA
# 4     3995 23rd St  San Francisco          CA 94114     USA

# %%
list(df6.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df6
# Out:
#     ID          Address           City             State Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees
# ID
# 1        Madeira          8
# 2    Bready Shop         15
# 3    Super River         25
# 4     Ben's Shop         10
# 5        Sanchez         12
# 6     Richvalley         20

# %%
df6.iloc[1:3,1:3]
# Out:
#            Address           City
# ID
# 2   735 Dolores St  San Francisco
# 3      332 Hill St  San Francisco

# %%
df6
# Out:
#     ID          Address           City             State Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees
# ID
# 1        Madeira          8
# 2    Bready Shop         15
# 3    Super River         25
# 4     Ben's Shop         10
# 5        Sanchez         12
# 6     Richvalley         20

# %%
df6.drop("City", 1)
# Out:
#     ID          Address             State Country          Name  Employees
# ID
# 1    1     3666 21st St          CA 94114     USA       Madeira          8
# 2    2   735 Dolores St          CA 94119     USA   Bready Shop         15
# 3    3      332 Hill St  California 94114     USA   Super River         25
# 4    4     3995 23rd St          CA 94114     USA    Ben's Shop         10
# 5    5  1056 Sanchez St        California     USA       Sanchez         12
# 6    6  551 Alvarado St          CA 94114     USA    Richvalley         20

# %%
df6
# Out:
#     ID          Address           City             State Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees
# ID
# 1        Madeira          8
# 2    Bready Shop         15
# 3    Super River         25
# 4     Ben's Shop         10
# 5        Sanchez         12
# 6     Richvalley         20

# %%
df6.drop(3, 0)
# Out:
#     ID          Address           City       State Country         Name  \
# ID
# 1    1     3666 21st St  San Francisco    CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 4    4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco  California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 4          10
# 5          12
# 6          20

# %%
df6.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
len(df6.index)
# Out:
# 6

# %%
df6["Continent"]=df6.shape[0]*["North America"]

# %%
df6
# Out:
#     ID          Address           City             State Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees      Continent
# ID
# 1        Madeira          8  North America
# 2    Bready Shop         15  North America
# 3    Super River         25  North America
# 4     Ben's Shop         10  North America
# 5        Sanchez         12  North America
# 6     Richvalley         20  North America

# %%
df6["Continent"]=df6["Country"] + ", " + df6["Continent"]

# %%
df6
# Out:
#     ID          Address           City             State Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees           Continent
# ID
# 1        Madeira          8  USA, North America
# 2    Bready Shop         15  USA, North America
# 3    Super River         25  USA, North America
# 4     Ben's Shop         10  USA, North America
# 5        Sanchez         12  USA, North America
# 6     Richvalley         20  USA, North America

# %%
df6_t = df6.T

# %%
df6_t
# Out:
# ID                          1                   2                   3  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df6_t[7]=[7, "My Address", "My City", "My State", "My Country", "My Name", "My Employees", "My Continent"]

# %%
df6_t
# Out:
# ID                          1                   2                   3  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6  \
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df6 = df6_t.T
df6
# Out:
#    ID          Address           City             State     Country  \
# ID
# 1   1     3666 21st St  San Francisco          CA 94114         USA
# 2   2   735 Dolores St  San Francisco          CA 94119         USA
# 3   3      332 Hill St  San Francisco  California 94114         USA
# 4   4     3995 23rd St  San Francisco          CA 94114         USA
# 5   5  1056 Sanchez St  San Francisco        California         USA
# 6   6  551 Alvarado St  San Francisco          CA 94114         USA
# 7   7       My Address        My City          My State  My Country
#
#             Name     Employees           Continent
# ID
# 1        Madeira             8  USA, North America
# 2    Bready Shop            15  USA, North America
# 3    Super River            25  USA, North America
# 4     Ben's Shop            10  USA, North America
# 5        Sanchez            12  USA, North America
# 6     Richvalley            20  USA, North America
# 7        My Name  My Employees        My Continent

# %%
df6.iloc[6,6]
# Out:
# 'My Employees'

# %%
df6.iloc[6,6] = 999

# %%
df6
# Out:
#    ID          Address           City             State     Country  \
# ID
# 1   1     3666 21st St  San Francisco          CA 94114         USA
# 2   2   735 Dolores St  San Francisco          CA 94119         USA
# 3   3      332 Hill St  San Francisco  California 94114         USA
# 4   4     3995 23rd St  San Francisco          CA 94114         USA
# 5   5  1056 Sanchez St  San Francisco        California         USA
# 6   6  551 Alvarado St  San Francisco          CA 94114         USA
# 7   7       My Address        My City          My State  My Country
#
#             Name Employees           Continent
# ID
# 1        Madeira         8  USA, North America
# 2    Bready Shop        15  USA, North America
# 3    Super River        25  USA, North America
# 4     Ben's Shop        10  USA, North America
# 5        Sanchez        12  USA, North America
# 6     Richvalley        20  USA, North America
# 7        My Name       999        My Continent

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n=nom.geocode("3995 23rd St, San Fancisco, USA")

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df_new = pandas.read_csv("resources/supermarkets/supermarkets.csv")

# %%
df_new
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_new["Address"] = df_new["Address"] + ", " + df_new["City"] + ", " + df_new["State"] + ", " + df_new["Country"]

# %%
df_new
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df_new["Coordinates"] = df_new["Address"].apply(nom.geocode)
df_new
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df_new.iloc[0,7]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df_new.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df_new["Latitude"] = df_new["Coordinates"].apply(lambda x: x.latitude if x != None else None)

# %%
df_new
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df_new["Longitude"] = df_new["Coordinates"].apply(lambda x: x.longitude)

# %%
df_new
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...

# %%
df_new.drop("Coordinates", 1)
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees   Latitude   Longitude
# 0          CA 94114     USA      Madeira          8  37.756648 -122.429375
# 1          CA 94119     USA  Bready Shop         15  37.757819 -122.425337
# 2  California 94114     USA  Super River         25  37.755875 -122.428816
# 3          CA 94114     USA   Ben's Shop         10  37.752922 -122.431697
# 4        California     USA      Sanchez         12  37.752131 -122.430028
# ...
